# %%
'''
Created on 22/01/2020
@author: B Akash
'''
'''
problem statement:
Write a Python program to plot quantities which have an x and y position 
'''

from matplotlib import pyplot as plt
x=[1,2,3,4,5]
y=[3,2,6,4,3]
x1=[1,2,3,4,5]
y1=[9,8,7,5,1]
plt.plot(x,y,"bs",x1,y1,"ro")
plt.show()
